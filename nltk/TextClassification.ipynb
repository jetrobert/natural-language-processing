# %% [markdown]
# # gender classifier

# %%
from __future__ import print_function
import nltk
from nltk.corpus import brown

# %%
def gender_features(word): 
        return {'last_letter': word[-1]} 

gender_features('Shrek')
# Out:
# {'last_letter': 'k'}

# %%
from nltk.corpus import names
import random

names = ([(name, 'male') for name in names.words('male.txt')] + [(name, 'female') for name in names.words('female.txt')]) 
random.shuffle(names) 
featuresets = [(gender_features(n), g) for (n,g) in names] 
train_set, test_set = featuresets[500:], featuresets[:500]

# %% [markdown]
# # Naive Bayes Classifier

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)
classifier.classify(gender_features('Neo'))
# Out:
# 'male'

# %%
classifier.classify(gender_features('Trinity'))
# Out:
# 'female'

# %%
print( nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.762

# %%
classifier.show_most_informative_features(5)
# Out:
# Most Informative Features
#              last_letter = 'a'            female : male   =     34.2 : 1.0
#              last_letter = 'k'              male : female =     31.4 : 1.0
#              last_letter = 'f'              male : female =     16.0 : 1.0
#              last_letter = 'p'              male : female =     11.9 : 1.0
#              last_letter = 'v'              male : female =     10.6 : 1.0

# %%
from nltk.classify import apply_features 
train_set = apply_features(gender_features, names[500:])
test_set = apply_features(gender_features, names[:500])
train_set
# Out:
# [({'last_letter': 'l'}, 'male'), ({'last_letter': 'y'}, 'male'), ...]

# %%
def gender_features2(name): 
    features = {} 
    features["firstletter"] = name[0].lower()
    features["lastletter"] = name[-1].lower() 
    for letter in 'abcdefghijklmnopqrstuvwxyz': 
        features["count(%s)" % letter] = name.lower().count(letter) 
        features["has(%s)" % letter] = (letter in name.lower()) 
    return features  

gender_features2('John')
# Out:
# {'count(a)': 0,
#  'count(b)': 0,
#  'count(c)': 0,
#  'count(d)': 0,
#  'count(e)': 0,
#  'count(f)': 0,
#  'count(g)': 0,
#  'count(h)': 1,
#  'count(i)': 0,
#  'count(j)': 1,
#  'count(k)': 0,
#  'count(l)': 0,
#  'count(m)': 0,
#  'count(n)': 1,
#  'count(o)': 1,
#  'count(p)': 0,
#  'count(q)': 0,
#  'count(r)': 0,
#  'count(s)': 0,
#  'count(t)': 0,
#  'count(u)': 0,
#  'count(v)': 0,
#  'count(w)': 0,
#  'count(x)': 0,
#  'count(y)': 0,
#  'count(z)': 0,
#  'firstletter': 'j',
#  'has(a)': False,
#  'has(b)': False,
#  'has(c)': False,
#  'has(d)': False,
#  'has(e)': False,
#  'has(f)': False,
#  'has(g)': False,
#  'has(h)': True,
#  'has(i)': False,
#  'has(j)': True,
#  'has(k)': False,
#  'has(l)': False,
#  'has(m)': False,
#  'has(n)': True,
#  'has(o)': True,
#  'has(p)': False,
#  'has(q)': False,
#  'has(r)': False,
#  'has(s)': False,
#  'has(t)': False,
#  'has(u)': False,
#  'has(v)': False,
#  'has(w)': False,
#  'has(x)': False,
#  'has(y)': False,
#  'has(z)': False,
#  'lastletter': 'n'}

# %%
featuresets = [(gender_features2(n), g) for (n,g) in names] 
train_set, test_set = featuresets[500:], featuresets[:500] 

classifier = nltk.NaiveBayesClassifier.train(train_set)  
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.79

# %%
train_names = names[1500:]
devtest_names = names[500:1500] 
test_names = names[:500] 

train_set = [(gender_features(n), g) for (n,g) in train_names] 
devtest_set = [(gender_features(n), g) for (n,g) in devtest_names] 
test_set = [(gender_features(n), g) for (n,g) in test_names] 

classifier = nltk.NaiveBayesClassifier.train(train_set) 
print(nltk.classify.accuracy(classifier, devtest_set))
# Out:
# 0.762

# %%
errors = [] 
for (name, tag) in devtest_names: 
    guess = classifier.classify(gender_features(name)) 
    if guess != tag: 
        errors.append( (tag, guess, name) ) 
        
for (tag, guess, name) in sorted(errors): # doctest: +ELLIPSIS +NORMALIZE_WHITESPACE
    print('correct=%-8s guess=%-8s name=%-30s' % (tag, guess, name))
# Out:
# correct=female   guess=male     name=Abagail
# correct=female   guess=male     name=Adrian
# correct=female   guess=male     name=Aeriel
# correct=female   guess=male     name=Alisun
# correct=female   guess=male     name=Amargo
# correct=female   guess=male     name=Aurel
# correct=female   guess=male     name=Averil
# correct=female   guess=male     name=Bab
# correct=female   guess=male     name=Bel
# correct=female   guess=male     name=Bell
# correct=female   guess=male     name=Berget
# correct=female   guess=male     name=Bess
# correct=female   guess=male     name=Bev
# correct=female   guess=male     name=Bidget
# correct=female   guess=male     name=Brandais
# correct=female   guess=male     name=Bridget
# correct=female   guess=male     name=Brit
# correct=female   guess=male     name=Carilyn
# correct=female   guess=male     name=Carlyn
# correct=female   guess=male     name=Carolann
# correct=female   guess=male     name=Catherin
# correct=female   guess=male     name=Cathyleen
# correct=female   guess=male     name=Catlin
# correct=female   guess=male     name=Charlot
# correct=female   guess=male     name=Charmion
# correct=female   guess=male     name=Cher
# correct=female   guess=male     name=Chriss
# correct=female   guess=male     name=Christean
# correct=female   guess=male     name=Colleen
# correct=female   guess=male     name=Cybill
# correct=female   guess=male     name=Darryl
# correct=female   guess=male     name=Diahann
# correct=female   guess=male     name=Dyan
# correct=female   guess=male     name=Francis
# correct=female   guess=male     name=Gabriel
# correct=female   guess=male     name=Gennifer
# correct=female   guess=male     name=Gert
# correct=female   guess=male     name=Glynis
# correct=female   guess=male     name=Glynnis
# correct=female   guess=male     name=Gwenn
# correct=female   guess=male     name=Hazel
# correct=female   guess=male     name=Hedwig
# correct=female   guess=male     name=Helyn
# correct=female   guess=male     name=Imogen
# correct=female   guess=male     name=Ingeborg
# correct=female   guess=male     name=Isador
# correct=female   guess=male     name=Isobel
# correct=female   guess=male     name=Jacklin
# correct=female   guess=male     name=Jaclin
# correct=female   guess=male     name=Jacquelyn
# correct=female   guess=male     name=Janifer
# correct=female   guess=male     name=Janis
# correct=female   guess=male     name=Jaquelyn
# correct=female   guess=male     name=Jean
# correct=female   guess=male     name=Jeniffer
# correct=female   guess=male     name=Jillian
# correct=female   guess=male     name=Joann
# correct=female   guess=male     name=Kit
# correct=female   guess=male     name=Laurel
# correct=female   guess=male     name=Madalyn
# correct=female   guess=male     name=Madelin
# correct=female   guess=male     name=Madlin
# correct=female   guess=male     name=Manon
# correct=female   guess=male     name=Margalit
# correct=female   guess=male     name=Margaret
# correct=female   guess=male     name=Marian
# correct=female   guess=male     name=Marillin
# correct=female   guess=male     name=Marlo
# correct=female   guess=male     name=Maryann
# correct=female   guess=male     name=Maureen
# correct=female   guess=male     name=Meaghan
# correct=female   guess=male     name=Meghann
# correct=female   guess=male     name=Mehetabel
# correct=female   guess=male     name=Mellisent
# correct=female   guess=male     name=Millicent
# correct=female   guess=male     name=Nan
# correct=female   guess=male     name=Nell
# correct=female   guess=male     name=Nil
# correct=female   guess=male     name=Pam
# correct=female   guess=male     name=Perl
# correct=female   guess=male     name=Pet
# correct=female   guess=male     name=Philis
# correct=female   guess=male     name=Ragnhild
# correct=female   guess=male     name=Rahal
# correct=female   guess=male     name=Raynell
# correct=female   guess=male     name=Rhianon
# correct=female   guess=male     name=Rianon
# correct=female   guess=male     name=Robbin
# correct=female   guess=male     name=Robbyn
# correct=female   guess=male     name=Robyn
# correct=female   guess=male     name=Ros
# correct=female   guess=male     name=Rosamond
# correct=female   guess=male     name=Roslyn
# correct=female   guess=male     name=Row
# correct=female   guess=male     name=Ruthann
# correct=female   guess=male     name=Sallyann
# correct=female   guess=male     name=Sean
# correct=female   guess=male     name=Shanon
# correct=female   guess=male     name=Shaylyn
# correct=female   guess=male     name=Shir
# correct=female   guess=male     name=Sib
# correct=female   guess=male     name=Sileas
# correct=female   guess=male     name=Siobhan
# correct=female   guess=male     name=Starlin
# correct=female   guess=male     name=Susan
# correct=female   guess=male     name=Suzan
# correct=female   guess=male     name=Tamiko
# correct=female   guess=male     name=Taryn
# correct=female   guess=male     name=Tatum
# correct=female   guess=male     name=Van
# correct=female   guess=male     name=Velvet
# correct=female   guess=male     name=Venus
# correct=female   guess=male     name=Vivian
# correct=female   guess=male     name=Wilow
# correct=male     guess=female   name=Abby
# correct=male     guess=female   name=Aguste
# correct=male     guess=female   name=Alfonse
# correct=male     guess=female   name=Ambrose
# correct=male     guess=female   name=Arnie
# correct=male     guess=female   name=Ashley
# correct=male     guess=female   name=Ave
# correct=male     guess=female   name=Avery
# correct=male     guess=female   name=Baily
# correct=male     guess=female   name=Barde
# correct=male     guess=female   name=Bartie
# correct=male     guess=female   name=Brodie
# correct=male     guess=female   name=Carleigh
# correct=male     guess=female   name=Carlie
# correct=male     guess=female   name=Chane
# correct=male     guess=female   name=Chauncey
# correct=male     guess=female   name=Christophe
# correct=male     guess=female   name=Cobbie
# correct=male     guess=female   name=Connolly
# correct=male     guess=female   name=Conroy
# correct=male     guess=female   name=Dante
# correct=male     guess=female   name=Dave
# correct=male     guess=female   name=Davy
# correct=male     guess=female   name=Douggie
# correct=male     guess=female   name=Drake
# correct=male     guess=female   name=Dwaine
# correct=male     guess=female   name=Edie
# correct=male     guess=female   name=Ernie
# correct=male     guess=female   name=Franky
# correct=male     guess=female   name=Garry
# correct=male     guess=female   name=Gordie
# correct=male     guess=female   name=Grady
# correct=male     guess=female   name=Gregory
# correct=male     guess=female   name=Griffith
# correct=male     guess=female   name=Hari
# correct=male     guess=female   name=Harry
# correct=male     guess=female   name=Henri
# correct=male     guess=female   name=Henry
# correct=male     guess=female   name=Herbie
# correct=male     guess=female   name=Hewie
# correct=male     guess=female   name=Hymie
# correct=male     guess=female   name=Jay
# correct=male     guess=female   name=Jerome
# correct=male     guess=female   name=Johny
# correct=male     guess=female   name=Jonah
# correct=male     guess=female   name=Jordy
# correct=male     guess=female   name=Jorge
# correct=male     guess=female   name=Julie
# correct=male     guess=female   name=Keefe
# correct=male     guess=female   name=Kelsey
# correct=male     guess=female   name=Kenneth
# correct=male     guess=female   name=Klee
# correct=male     guess=female   name=Lawrence
# correct=male     guess=female   name=Lay
# correct=male     guess=female   name=Lenny
# correct=male     guess=female   name=Lex
# correct=male     guess=female   name=Lorrie
# correct=male     guess=female   name=Luke
# correct=male     guess=female   name=Mace
# correct=male     guess=female   name=Marty
# correct=male     guess=female   name=Maurice
# correct=male     guess=female   name=Maurie
# correct=male     guess=female   name=Maurise
# correct=male     guess=female   name=Mendie
# correct=male     guess=female   name=Merry
# correct=male     guess=female   name=Mischa
# correct=male     guess=female   name=Montgomery
# correct=male     guess=female   name=Munroe
# correct=male     guess=female   name=Murray
# correct=male     guess=female   name=Neale
# correct=male     guess=female   name=Nevile
# correct=male     guess=female   name=Orville
# correct=male     guess=female   name=Osborne
# correct=male     guess=female   name=Pasquale
# correct=male     guess=female   name=Pembroke
# correct=male     guess=female   name=Quigly
# correct=male     guess=female   name=Ralph
# correct=male     guess=female   name=Rene
# correct=male     guess=female   name=Ricky
# correct=male     guess=female   name=Ritch
# correct=male     guess=female   name=Roderich
# correct=male     guess=female   name=Rodney
# correct=male     guess=female   name=Rodrique
# correct=male     guess=female   name=Roni
# correct=male     guess=female   name=Roscoe
# correct=male     guess=female   name=Rudie
# correct=male     guess=female   name=Sammie
# correct=male     guess=female   name=Samuele
# correct=male     guess=female   name=Sandy
# correct=male     guess=female   name=Shea
# correct=male     guess=female   name=Shelley
# correct=male     guess=female   name=Sherlocke
# correct=male     guess=female   name=Siffre
# correct=male     guess=female   name=Sinclare
# correct=male     guess=female   name=Skelly
# correct=male     guess=female   name=Sonny
# correct=male     guess=female   name=Stanley
# correct=male     guess=female   name=Steve
# correct=male     guess=female   name=Stinky
# correct=male     guess=female   name=Sunny
# correct=male     guess=female   name=Tallie
# correct=male     guess=female   name=Teddy
# correct=male     guess=female   name=Terrence
# correct=male     guess=female   name=Terry
# correct=male     guess=female   name=Thane
# correct=male     guess=female   name=Timothy
# correct=male     guess=female   name=Tome
# correct=male     guess=female   name=Tommie
# correct=male     guess=female   name=Tore
# correct=male     guess=female   name=Torrence
# correct=male     guess=female   name=Towney
# correct=male     guess=female   name=Tracey
# correct=male     guess=female   name=Tremaine
# correct=male     guess=female   name=Tyrone
# correct=male     guess=female   name=Valentine
# correct=male     guess=female   name=Vassily
# correct=male     guess=female   name=Wadsworth
# correct=male     guess=female   name=Wallie
# correct=male     guess=female   name=Wiley
# correct=male     guess=female   name=Wolfy
# correct=male     guess=female   name=Zachary
# correct=male     guess=female   name=Zebadiah
# correct=male     guess=female   name=Zebedee
# correct=male     guess=female   name=Zippy

# %% [markdown]
# ### new feature----name with last 2 letters

# %%
def gender_features(word): 
    return {'suffix1': word[-1:], 'suffix2': word[-2:]}

train_set = [(gender_features(n), g) for (n,g) in train_names] 
devtest_set = [(gender_features(n), g) for (n,g) in devtest_names] 

classifier = nltk.NaiveBayesClassifier.train(train_set) 
print(nltk.classify.accuracy(classifier, devtest_set))
# Out:
# 0.788

# %% [markdown]
# # document classification

# %%
from nltk.corpus import movie_reviews 
documents = [(list(movie_reviews.words(fileid)), category) 
             for category in movie_reviews.categories() 
             for fileid in movie_reviews.fileids(category)] 

random.shuffle(documents)

# %%
all_words = nltk.FreqDist(w.lower() for w in movie_reviews.words()) 
word_features = list(all_words.keys())[:2000] 

def document_features(document): 
    document_words = set(document) 
    features = {} 
    for word in word_features: 
        features['contains(%s)' % word] = (word in document_words) 
        
    return features

print(document_features(movie_reviews.words('pos/cv957_8737.txt')))
# Out:
# {'contains(sure)': False, 'contains(viewed)': False, 'contains(enjoyability)': False, 'contains(subterfuge)': False, 'contains(strikingly)': False, 'contains(matriarch)': False, 'contains(supposed)': False, 'contains(civic)': False, 'contains(formulated)': False, 'contains(meager)': False, 'contains(ushers)': False, 'contains(inquiries)': False, 'contains(seclusion)': False, 'contains(accelerated)': False, 'contains(widowed)': False, 'contains(inclined)': False, 'contains(intermission)': False, 'contains(ledges)': False, 'contains(smithereens)': False, 'contains(sctv)': False, 'contains(ogle)': False, 'contains(shin)': False, 'contains(specified)': False, 'contains(modem)': False, 'contains(neurologist)': False, 'contains(operates)': False, 'contains(extremel)': False, 'contains(adult)': False, 'contains(cries)': False, 'contains(negligees)': False, 'contains(laboured)': False, 'contains(marvelling)': False, 'contains(snarling)': False, 'contains(dashing)': False, 'contains(exposes)': False, 'contains(colour)': False, 'contains(soundtrack)': False, 'contains(morals)': False, 'contains(oriental)': False, 'contains(sensibilities)': False, 'contains(ratcheted)': False, 'contains(claps)': False, 'contains(recurring)': False, 'contains(naming)': False, 'contains(combines)': False, 'contains(bagpipes)': False, 'contains(eclairs)': False, 'contains(theatrical)': False, 'contains(publication)': False, 'contains(tossable)': False, 'contains(kat)': False, 'contains(ellie)': False, 'contains(sick)': False, 'contains(lumpy)': False, 'contains(slimes)': False, 'contains(sid)': False, 'contains(gorey)': False, 'contains(goofiest)': False, 'contains(shimmering)': False, 'contains(expression)': False, 'contains(fowl)': False, 'contains(hiding)': False, 'contains(tiresomely)': False, 'contains(commercialist)': False, 'contains(ignite)': False, 'contains(inordinate)': False, 'contains(motive)': False, 'contains(kowtowing)': False, 'contains(admittance)': False, 'contains(listened)': False, 'contains(roasting)': False, 'contains(donager)': False, 'contains(redoubtable)': False, 'contains(system)': False, 'contains(emerges)': False, 'contains(renamed)': False, 'contains(iron)': False, 'contains(contradiction)': False, 'contains(dusty)': False, 'contains(rosette)': False, 'contains(intros)': False, 'contains(complaining)': False, 'contains(voiceovers)': False, 'contains(restrained)': False, 'contains(segal)': False, 'contains(predetermine)': False, 'contains(cod)': False, 'contains(gripped)': False, 'contains(innocently)': False, 'contains(closese)': False, 'contains(exfoliating)': False, 'contains(relic)': False, 'contains(dale)': False, 'contains(finer)': False, 'contains(ses)': False, 'contains(sluizer)': False, 'contains(superman)': False, 'contains(ensued)': False, 'contains(bred)': False, 'contains(animator)': False, 'contains(unconventionality)': False, 'contains(palatable)': False, 'contains(relish)': False, 'contains(grant)': False, 'contains(unblemished)': False, 'contains(spadowski)': False, 'contains(unlovable)': False, 'contains(larina)': False, 'contains(tricia)': False, 'contains(renegade)': False, 'contains(inaccuracies)': False, 'contains(kombat)': False, 'contains(sobol)': False, 'contains(electoral)': False, 'contains(skins)': False, 'contains(appliances)': False, 'contains(again)': False, 'contains(godawa)': False, 'contains(____________________________________________)': False, 'contains(belies)': False, 'contains(nachos)': False, 'contains(actuality)': False, 'contains(hallucinogenic)': False, 'contains(lords)': False, 'contains(slushee)': False, 'contains(secular)': False, 'contains(poppins)': False, 'contains(years)': False, 'contains(unexistent)': False, 'contains(stunner)': False, 'contains(preceeding)': False, 'contains(consult)': False, 'contains(swope)': False, 'contains(disqualified)': False, 'contains(pa)': False, 'contains(unironic)': False, 'contains(shpadoinkle)': False, 'contains(paltrow)': False, 'contains(weakn ...

# %%
featuresets = [(document_features(d), c) for (d,c) in documents] 
train_set, test_set = featuresets[100:], featuresets[:100] 
classifier = nltk.NaiveBayesClassifier.train(train_set) 
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.64

# %%
classifier.show_most_informative_features(5)
# Out:
# Most Informative Features
#   contains(refreshingly) = True              pos : neg    =      8.4 : 1.0
#     contains(weaknesses) = True              pos : neg    =      8.4 : 1.0
#         contains(denial) = True              pos : neg    =      7.7 : 1.0
#           contains(moss) = True              pos : neg    =      7.0 : 1.0
#        contains(insipid) = True              neg : pos    =      6.6 : 1.0

# %%
from nltk.corpus import brown 
suffix_fdist = nltk.FreqDist() 
for word in brown.words(): 
    word = word.lower() 
    suffix_fdist[word[-1:]] 
    suffix_fdist[word[-2:]]
    suffix_fdist[word[-3:]]
    
common_suffixes = list(suffix_fdist.keys())[:100] 
print(common_suffixes)
# Out:
# []

# %%
def pos_features(word):
    features = {} 
    for suffix in common_suffixes: 
        features['endswith(%s)' % suffix] = word.lower().endswith(suffix) 
    return features

# %% [markdown]
# # decision tree classifier

# %%
tagged_words = brown.tagged_words(categories='news') 
featuresets = [(pos_features(n), g) for (n,g) in tagged_words] 
size = int(len(featuresets) * 0.1) 
train_set, test_set = featuresets[size:], featuresets[:size]

classifier = nltk.DecisionTreeClassifier.train(train_set) 
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.14221780208851317

# %%
classifier.classify(pos_features('cats'))
# Out:
# 'NN'

# %%
 print(classifier.pseudocode(depth=4))
# Out:
# return 'NN'

# %% [markdown]
# # context features classifier

# %%
def pos_features(sentence, i): 
    features = {"suffix(1)": sentence[i][-1:], 
                "suffix(2)": sentence[i][-2:], 
                "suffix(3)": sentence[i][-3:]} 
    if i == 0: 
        features["prev-word"] = "<START>" 
    else: 
        features["prev-word"] = sentence[i-1]
    return features 

pos_features(brown.sents()[0], 8)
# Out:
# {'prev-word': 'an', 'suffix(1)': 'n', 'suffix(2)': 'on', 'suffix(3)': 'ion'}

# %%
tagged_sents = brown.tagged_sents(categories='news') 
featuresets = []  
for tagged_sent in tagged_sents: 
    untagged_sent = nltk.tag.untag(tagged_sent) 
    for i, (word, tag) in enumerate(tagged_sent):
         featuresets.append((pos_features(untagged_sent, i), tag)) 
            
size = int(len(featuresets) * 0.1) 
train_set, test_set = featuresets[size:], featuresets[:size]

classifier = nltk.NaiveBayesClassifier.train(train_set) 
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.7891596220785678

# %% [markdown]
# # sequential classifier

# %%
def pos_features(sentence, i, history): 
    features = {"suffix(1)": sentence[i][-1:], 
                "suffix(2)": sentence[i][-2:], 
                "suffix(3)": sentence[i][-3:]}
    if i == 0: 
        features["prev-word"] = "<START>" 
        features["prev-tag"] = "<START>" 
    else: 
        features["prev-word"] = sentence[i-1] 
        features["prev-tag"] = history[i-1] 
    return features 

class ConsecutivePosTagger(nltk.TaggerI):
    def __init__(self, train_sents): 
        train_set = [] 
        for tagged_sent in train_sents: 
            untagged_sent = nltk.tag.untag(tagged_sent) 
            history = [] 
            for i, (word, tag) in enumerate(tagged_sent):
                featureset = pos_features(untagged_sent, i, history) 
                train_set.append((featureset, tag)) 
                history.append(tag) 
        self.classifier = nltk.NaiveBayesClassifier.train(train_set) 
    def tag(self, sentence): 
        history = [] 
        for i, word in enumerate(sentence): 
            featureset = pos_features(sentence, i, history) 
            tag = self.classifier.classify(featureset) 
            history.append(tag)   
        return zip(sentence, history) 

tagged_sents = brown.tagged_sents(categories='news') 
size = int(len(tagged_sents) * 0.1) 
train_sents, test_sents = tagged_sents[size:], tagged_sents[:size] 

tagger = ConsecutivePosTagger(train_sents)
print(tagger.evaluate(test_sents))
# Out:
# 0.7980528511821975

# %% [markdown]
# # sentence segmentation

# %%
sents = nltk.corpus.treebank_raw.sents() 
tokens = [] 
boundaries = set() 
offset = 0 
for sent in nltk.corpus.treebank_raw.sents(): 
    tokens.extend(sent) 
    offset += len(sent) 
    boundaries.add(offset-1) 
    
def punct_features(tokens, i): 
    return {'next-word-capitalized': tokens[i+1][0].isupper(), 
                'prevword': tokens[i-1].lower(),
                 'punct': tokens[i], 
                 'prev-word-is-one-char': len(tokens[i-1]) == 1} 

featuresets = [(punct_features(tokens, i), (i in boundaries)) 
               for i in range(1, len(tokens)-1) if tokens[i] in '.?!'] 

size = int(len(featuresets) * 0.1) 
train_set, test_set = featuresets[size:], featuresets[:size]

classifier = nltk.NaiveBayesClassifier.train(train_set) 
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.936026936026936

# %%
def segment_sentences(words): 
    start = 0 
    sents = [] 
    for i, word in words: 
        if word in '.?!' and classifier.classify(words, i) == True: 
            sents.append(words[start:i+1]) 
            start = i+1 
    if start < len(words): 
        sents.append(words[start:])

# %% [markdown]
# # dialogue class

# %%
import nltk
posts = nltk.corpus.nps_chat.xml_posts()[:10000]

# %%
def dialogue_act_features(post): 
    features = {} 
    for word in nltk.word_tokenize(post): 
        features['contains(%s)' % word.lower()] = True 
    return features

featuresets = [(dialogue_act_features(post.text), post.get('class')) for post in posts] 

size = int(len(featuresets) * 0.1)
train_set, test_set = featuresets[size:], featuresets[:size] 
classifier = nltk.NaiveBayesClassifier.train(train_set) 
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.668

# %% [markdown]
# # Recognizing textual entailment

# %%
def rte_features(rtepair): 
    extractor = nltk.RTEFeatureExtractor(rtepair) 
    features = {}
    features['word_overlap'] = len(extractor.overlap('word')) 
    features['word_hyp_extra'] = len(extractor.hyp_extra('word'))
    features['ne_overlap'] = len(extractor.overlap('ne')) 
    features['ne_hyp_extra'] = len(extractor.hyp_extra('ne')) 
    return features 

rtepair = nltk.corpus.rte.pairs(['rte3_dev.xml'])[33] 
extractor = nltk.RTEFeatureExtractor(rtepair) 
print(extractor.text_words)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# d:\programfiles\python35\lib\site-packages\nltk\corpus\util.py in __load(self)
#      79             except LookupError as e:
# ---> 80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      81                 except LookupError: raise e
#
# d:\programfiles\python35\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     647     resource_not_found = '\n%s\n%s\n%s' % (sep, msg, sep)
# --> 648     raise LookupError(resource_not_found)
#     649
#
# LookupError:
# **********************************************************************
#   Resource 'corpora/rte.zip/rte/' not found.  Please use the NLTK
#   Downloader to obtain the resource:  >>> nltk.download()
#   Searched in:
#     - 'C:\\Users\\jet/nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - 'd:\\programfiles\\python35\\nltk_data'
#     - 'd:\\programfiles\\python35\\lib\\nltk_data'
#     - 'C:\\Users\\jet\\AppData\\Roaming\\nltk_data'
# **********************************************************************
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-3-c21f34cd48cc> in <module>()
#       8     return features
#       9
# ---> 10 rtepair = nltk.corpus.rte.pairs(['rte3_dev.xml'])[33]
#      11 extractor = nltk.RTEFeatureExtractor(rtepair)
#      12 print(extractor.text_words)
#
# d:\programfiles\python35\lib\site-packages\nltk\corpus\util.py in __getattr__(self, attr)
#     114             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     115
# --> 116         self.__load()
#     117         # This looks circular, but its not, since __load() changes our
#     118         # __class__ to something new:
#
# d:\programfiles\python35\lib\site-packages\nltk\corpus\util.py in __load(self)
#      79             except LookupError as e:
#      80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
# ---> 81                 except LookupError: raise e
#      82
#      83         # Load the corpus.
#
# d:\programfiles\python35\lib\site-packages\nltk\corpus\util.py in __load(self)
#      76         else:
#      77             try:
# ---> 78                 root = nltk.data.find('{}/{}'.format(self.subdir, self.__name))
#      79             except LookupError as e:
#      80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#
# d:\programfiles\python35\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     646     sep = '*' * 70
#     647     resource_not_found = '\n%s\n%s\n%s' % (sep, msg, sep)
# --> 648     raise LookupError(resource_not_found)
#     649
#     650
#
# LookupError:
# **********************************************************************
#   Resource 'corpora/rte' not found.  Please use the NLTK
#   Downloader to obtain the resource:  >>> nltk.download()
#   Searched in:
#     - 'C:\\Users\\jet/nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - 'd:\\programfiles\\python35\\nltk_data'
#     - 'd:\\programfiles\\python35\\lib\\nltk_data'
#     - 'C:\\Users\\jet\\AppData\\Roaming\\nltk_data'
# **********************************************************************

# %%
from nltk.corpus import brown

file_ids = brown.fileids(categories='news')
size = int(len(file_ids) * 0.1) 
train_set = brown.tagged_sents(file_ids[size:]) 
test_set = brown.tagged_sents(file_ids[:size]) 

classifier = nltk.NaiveBayesClassifier.train(train_set)
print('Accuracy: %4.2f' % nltk.classify.accuracy(classifier, test_set))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-5e9036d93e6e> in <module>()
#       6 test_set = brown.tagged_sents(file_ids[:size])
#       7
# ----> 8 classifier = nltk.NaiveBayesClassifier.train(train_set)
#       9 print('Accuracy: %4.2f' % nltk.classify.accuracy(classifier, test_set))
#
# d:\programfiles\python35\lib\site-packages\nltk\classify\naivebayes.py in train(cls, labeled_featuresets, estimator)
#     192         # Count up how many times each feature value occurred, given
#     193         # the label and featurename.
# --> 194         for featureset, label in labeled_featuresets:
#     195             label_freqdist[label] += 1
#     196             for fname, fval in featureset.items():
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# # confusion matrix

# %%
def tag_list(tagged_sents): 
    return [tag for sent in tagged_sents for (word, tag) in sent] 

def apply_tagger(tagger, corpus): 
        return [tagger.tag(nltk.tag.untag(sent)) for sent in corpus] 

from nltk.corpus import brown
brown_tagged_sents = brown.tagged_sents(categories='news')
fd = nltk.FreqDist(brown.words())
word_list = fd.keys()
word_mapping = dict((w,w) if fd[w] > 3  else (w,'UNK')
                            for w in word_list)
brown_tagged_sent = brown.tagged_sents(categories='news')
training_size = int(len(brown_tagged_sents) * 0.9)
new_brown_tagged_sent = [[(word_mapping[wd],tag) for (wd,tag) in sent] for sent in brown_tagged_sent]
train_sents = new_brown_tagged_sent[:training_size]

t0 = nltk.DefaultTagger('NN')
t1 = nltk.UnigramTagger(train_sents, backoff=t0)
t2 = nltk.BigramTagger(train_sents, backoff=t1)

gold = tag_list(brown.tagged_sents(categories='editorial')) 
test = tag_list(apply_tagger(t2, brown.tagged_sents(categories='editorial'))) 
cm = nltk.ConfusionMatrix(gold, test)
print(cm)
# Out:
#            |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       W                                         |
#            |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            N                                                                                                                                                                                                                                                                                                                                                                            V                             D                                         |
#            |                                                                                                                                                                                                                                                                                                                                                        F              F         F         F                                                                                                        J                                                                                         N                             N                                                                                                                                                                                        P    P         P                                                                                                                                                                    B                             T                                         |
#            |                                                                                                                                                               B                                                                                                                                                                                        W              W         W         W                                                                                                        J                                                                                         N              N              S                                            N                                                                                                                       P    P              P    P    P    P    P    P    P                                                                                                                                                     N                        W    +                                         |
#            |                                                                                         A                                                                     E                             B    B              B    B                                                                                    D         D                        E         -              -         -         -    F         F    F         F    F                                                                     -         J    J         J         J                                  N    N              -              N    N    N    -              N    N    N                   P    N    N              N                                                 P    P         P              P    P         P    P    P         S    S    P    S    P    P    P                                                                                              V                   V         V    V         V    V    -         V    V         D    B    W              W              W      |
#            |                                                 -                                       B                   A    A         A    A         B              B    D                             E    E              E    E         C    C         C    C         C              D    D                        O         T                        X    F    A    F    F    I    F    J    F    N    W    F    W    W    F    W    W                                       I    I    I         J    J    T         J    J         J         J              M    M              N    N    N    N    T              S    N    N    T              P    P    P    N    N         S    P    P              R    N              O              P              P    P         P              P    P         S    S    P         S    S    S    S    S    S    S         Q                   R    R    R                        R         T         U         B    V    V         B         B    B         B    B    T         B    B         T    E    D              P              R      |
#            |                             *         ,         -         .         :    :              N                   P    P         T    T         E         B    E    Z                        B    R    R         B    Z    Z         C    C         D    D         S              O    O         D         D    Z         +                        +    W    T    W    W    N    W    J    W    N    -    W    -    -    W    -    -                             H         N    N    N         J    J    L         R    R         S         T              D    D              $    $    N    N    L         N    $    S    S    L              $    $    +    P    P         $    S    S              $    R              D              N         P    $    $         L    P         O    O         +    +    S    P    +    +    S    +    S    S    S         L                   B    B    B                        P         O         H         +    B    B         D         G    G         N    N    L         Z    Z         +    Z    T              O              B      |
#            |                             -         -         -         -         -    -    A    A    -    A         A    -    -         -    -         -    B    E    D    -    B    B    B    B    E    -    -    B    E    -    -         -    -         -    -         -         D    -    -    D    O    D    O    -         B    D    D    D         B    -    -    -    -    -    -    -    -    -    N    -    P    P    -    V    W         H    H    H    H    V         -    -    -         -    -    -    J    -    -    J    -    J    -         M    -    -         N    -    -    -    -    -    N    N    -    -    -    -         N    -    -    B    -    -    N    -    -    -         N    -    -    N         -         P    -    P    P    -    -    P    -    P    P    -    -    P    B    H    +    P    B    B    +    H    +    -    -         -    Q         R    -    -    -    R    R              -         -         -         P    -    -    V    -    V    -    -    V    -    -    -    V    -    -    W    B    -    -    W    W    -    W    W    -      |
#            |         '                   H         H    -    H         H         H    T    B    B    T    B    A    P    H    T    A    H    T    B    H    E    D    Z    H    E    E    E    E    R    H    T    E    Z    H    T    C    H    T    C    H    T    C    H    D    O    H    T    O    D    O    Z    H    D    E    T    T    T    E    E    A    T    C    I    T    J    T    N    T    N    N    P    P    V    B    D    H    V    V    V    V    Z    I    H    N    T    J    H    T    H    J    H    T    J    T    J    H    M    D    H    T    N    N    H    T    H    T    H    N    S    T    H    T    H    N    P    H    T    E    H    T    P    H    H    T    N    R    T    T    R    O    T    P    N    H    P    $    H    T    P    H    L    P    H    T    P    E    V    M    S    E    E    H    V    M    H    T    Q    H    L    R    B    H    N    T    B    B    R    R    H    T    H    U    H    V    P    H    T    B    H    B    H    T    B    H    T    H    B    H    T    D    E    H    H    P    P    T    P    R    H    ` |
#            |    '    '    (    )    *    L    ,    L    -    L    .    L    :    L    L    L    N    L    X    P    $    L    L    T    L    L    E    L    D    Z    *    L    G    M    N    R    *    L    L    Z    *    L    L    C    L    L    D    L    L    S    L    O    *    L    L    D    *    Z    *    L    T    Z    I    S    X    X    Z    T    L    C    N    L    J    L    N    L    S    P    L    O    B    Z    T    V    D    G    N    Z    *    N    L    C    L    J    L    L    L    R    L    L    S    L    T    L    D    *    L    L    N    $    L    L    L    L    L    S    $    L    L    L    L    P    $    L    L    Z    L    L    S    L    L    L    R    $    L    L    S    D    L    N    $    L    $    $    L    L    L    L    S    O    L    L    S    Z    Z    D    S    M    R    V    D    D    L    L    L    L    P    B    $    L    C    L    R    T    N    P    L    O    L    H    L    B    O    L    L    D    L    G    L    L    N    L    L    L    Z    L    L    T    Z    L    L    $    O    L    S    B    L    ` |
# -----------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#          ' |  <19>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#         '' |    . <382>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#          ( |    .    .  <95>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#          ) |    .    .    .  <95>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#          * |    .    .    .    . <304>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#       *-HL |    .    .    .    .    3   <.>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#          , |    .    .    .    .    .    .<2736>   5    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#       ,-HL |    .    .    .    .    .    .   22   <3>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#         -- |    .    .    .    .    .    .    .    . <191>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#      ---HL |    .    .    .    .    .    .    .    .    1   <.>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#          . |    .    .    .    .    .    .    .    .    .    .<2978>   2    8    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#       .-HL |    .    .    .    .    .    .    .    .    .    .   20   <1>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#          : |    .    .    .    .    .    .    .    .    .    .    .    . <108>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#       :-HL |    .    .    .    .    .    .    .    .    .    .    .    .   36   <.>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#       :-TL |    .    .    .    .    .    .    .    .    .    .    .    .    1    .   <.>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#        ABL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   <2>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   12    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#        ABN |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . <150>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    2    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#     ABN-TL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    2   <.>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#        ABX |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .  <30>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#         AP |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . <530>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    3    .    .    .    .    .    .    .    1    .    .    .    .    .    .    .    .    .    .   20    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   40    .    1    4    .    .    .    .    4    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#        AP$ |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   <1>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#      AP-HL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    4    .   <.>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    2    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#      AP-TL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    1    .    .   <.>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#         AT |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .<5306>   .    4    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#      AT-HL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   93   <.>   2    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#      AT-TL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   30    .  <13>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#         BE |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . <420>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#      BE-HL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    1   <.>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#        BED |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . <109>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#       BEDZ |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . <307>   .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    2    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#      BEDZ* |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   <2>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#    BEDZ-HL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   <.>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#        BEG |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .  <45>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#        BEM |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .  <19>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
# ...
#        VBZ |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .  166    .    .    .    .    .    .   61    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . <314>   3    .    .    .    .    .    .    .    .    .    .    .    . |
#     VBZ-HL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    7    .    .    .    .    .    .    2    .    .    .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    6   <1>   .    .    .    .    .    .    .    .    .    .    .    . |
#     VBZ-TL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    3    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   <.>   .    .    .    .    .    .    .    .    .    .    . |
#        WDT |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . <307>   .    .    .    .    .    .    .    .    .    . |
#    WDT+BEZ |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    2    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   <.>   .    .    .    .    .    .    .    .    . |
# WDT+BEZ-HL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   <.>   .    .    .    .    .    .    .    . |
#     WDT-HL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    3    .    .   <.>   .    .    .    .    .    .    . |
#        WP$ |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .  <11>   .    .    .    .    .    . |
#        WPO |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    5    .    .    .    .    .    .    .    .    .    .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   <8>   .    .    .    .    . |
#     WPO-TL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   <.>   .    .    .    . |
#        WPS |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   54    .    .    .    .    .    .    .    .    .    .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    5    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . <208>   .    .    . |
#        WRB |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    3    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    6    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . <251>   .    . |
#     WRB-HL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    3   <.>   . |
#         `` |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . <396>|
# -----------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# (row = reference; col = test)

# %% [markdown]
# # decision tree

# %%
import math 
def entropy(labels): 
    freqdist = nltk.FreqDist(labels) 
    probs = [freqdist.freq(l) for l in nltk.FreqDist(labels)] 
    return -sum([p * math.log(p,2) for p in probs]) 

print(entropy(['male', 'male', 'male', 'male']))
# Out:
# -0.0

# %%
print(entropy(['male', 'female', 'male', 'male']))
# Out:
# 0.8112781244591328

# %%
print(entropy(['female', 'male', 'female', 'male']))
# Out:
# 1.0
